# %% [markdown]
# # Informe:
#
# ## Introducción
#
# Datos: head y violinplots# Informe:
#
# ## Introducción
#
# Datos: head y violinplots
# Objetivo del tp e introducción a los modelos
#
# ## Métodos
# Preparación de datos: sacar datos faltantes, creación de features nuevas y eliminar las categóricas
#
# Separación en train y test: stratified split
# Con el set de training hacemos validación: grid search para buscar best hiperparametros en cada modelo
# Entrenamos cada modelo con el set de train y el mejor hiperparametro
# Testeamos el modelo con el set de test
#
# ## Resultados y Discusión
# Comparamos los diferentes modelos (ECM)
# Discusión de cuál método ajusta mejor

# %% [markdown]
# # Introducción

# %% [markdown]
# La base de datos de \textit{California Housing Prices} corresponde a un censo del año 1990 en la provincia de California, Estados Unidos. Cada entrada (fila de la tabla) es un distrito. El objetivo de este trabajo práctico fue predecir el valor de la variable \textit{median\_housing\_price} utilizando el resto de las variables del dataset. La estimación se realizó utilizando una serie de modelos lineales con parámetros de regularización. Se utilizaron las regresiones de Lasso, Ridge y Elastic Net.

# %% [markdown]
# Importamos los paquetes necesarios

# %%
# Python ≥3.5
import sys
assert sys.version_info >= (3, 5)

import numpy as np
import os
import seaborn as sns
import pandas as pd

# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# Scikit-Learn ≥0.20
import sklearn
assert sklearn.__version__ >= "0.20"


from sklearn.model_selection import StratifiedShuffleSplit
import matplotlib.pyplot as plt
from zlib import crc32
import hashlib
import matplotlib.image as mpimg
from sklearn.model_selection import train_test_split
from six.moves import urllib
from scipy import stats
from sklearn.metrics import mean_squared_error
from sklearn import metrics
from sklearn import linear_model
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.model_selection import (TimeSeriesSplit, KFold, ShuffleSplit,
StratifiedKFold, GroupShuffleSplit,
GroupKFold, StratifiedShuffleSplit,cross_val_score)
from sklearn.linear_model import Ridge
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import (OrdinalEncoder,OneHotEncoder)

# Donde guardar las figuras
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "end_to_end_project"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %% [markdown]
# Cargamos los datos y miramos las 5 primeras entradas

# %%
housing = pd.read_csv("data/housing.csv");
housing.head();

# %% [markdown]
# # Exploración de los datos

# %% [markdown]
# La base de datos cuenta con 9 variables

# %%
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
housing.iloc[:,0]
# Out:
# 0       -122.23
# 1       -122.22
# 2       -122.24
# 3       -122.25
# 4       -122.25
#           ...
# 20635   -121.09
# 20636   -121.21
# 20637   -121.22
# 20638   -121.32
# 20639   -121.24
# Name: longitude, Length: 20640, dtype: float64

# %%
colnames = housing.columns
fig = plt.figure(figsize=(16,16))
for i in range(1, 10):
    ax = plt.subplot(4, 3, i)
    ax.set_xlabel(colnames[i-1])
    sns.violinplot(data=housing.iloc[:,i-1])

# %% [markdown]
# La tabla cuenta con datos de 20640 distritos. Como se puede obsevar en la tabla que sigue, la variable total_bedrooms posee 207 datos faltantes.

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# Discretizamos la variable median_income en 5 categorías. Vemos que las proporciones categorías no son uniformes.

# %%
# Download the California image
images_path = os.path.join(PROJECT_ROOT_DIR, "images", "end_to_end_project")
os.makedirs(images_path, exist_ok=True)
DOWNLOAD_ROOT = "https://raw.githubusercontent.com/ageron/handson-ml2/master/"
filename = "california.png"
print("Downloading", filename)
url = DOWNLOAD_ROOT + "images/end_to_end_project/" + filename
urllib.request.urlretrieve(url, os.path.join(images_path, filename))
# Out:
# Downloading california.png
# ('./images/end_to_end_project/california.png',
#  <http.client.HTTPMessage at 0x7f7682fd08b0>)

# %%
california_img=mpimg.imread(os.path.join(images_path, filename))
ax = housing.plot(kind="scatter", x="longitude", y="latitude", figsize=(10,7),
                  s=housing['population']/100, label="Population",
                  c="median_house_value", cmap=plt.get_cmap("jet"),
                  colorbar=False, alpha=0.4)
plt.imshow(california_img, extent=[-124.55, -113.80, 32.45, 42.05], alpha=0.5,
           cmap=plt.get_cmap("jet"))
plt.ylabel("Latitude", fontsize=14)
plt.xlabel("Longitude", fontsize=14)

prices = housing["median_house_value"]
tick_values = np.linspace(prices.min(), prices.max(), 11)
cbar = plt.colorbar(ticks=tick_values/prices.max())
cbar.ax.set_yticklabels(["$%dk"%(round(v/1000)) for v in tick_values], fontsize=14)
cbar.set_label('Median House Value', fontsize=16)

plt.legend(fontsize=16)
save_fig("california_housing_prices_plot")
plt.show()
# Out:
# Saving figure california_housing_prices_plot

# %%
#Gráfico alternativo con mapa
import plotly.graph_objects as go
df = housing

fig = go.Figure(data=go.Scattergeo(
        lon = df['longitude'],
        lat = df['latitude'],
        mode = 'markers',
        marker_color = df['median_house_value'],
        ))

fig.update_layout(
        title = 'Valor de propiedades según locación',
        geo_scope='usa'
        
    )
fig.show()

# %%
# Correlación entre variables
corr_matrix = housing.corr()

paleta = sns.diverging_palette(150, 275, s=80, l=40, n=20)

with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(17, 12))
    ax = sns.heatmap(corr_matrix,
                     annot=True,
                     annot_kws={'size': 12},
                     fmt='.2f',
                     vmax=1, 
                     vmin=-1, 
                     square=True, 
                     linewidths=.01, 
                     linecolor='lightgray', 
                     cmap=paleta)

# %% [markdown]
# # Separación en train y test
#
# Empleamos la estrategia de muestreo estratificado utilizando la variable median_income, para no incluir un sesgo en el muestreo. Dividimos las observaciones en subgrupos homogéneos llamados "strata". Este método garantiza que el set de test sea representativo de toda la población.

# %%
housing["income_cat"] = pd.cut(housing["median_income"],
                               bins=[0., 1.5, 3.0, 4.5, 6., np.inf],
                               labels=[1, 2, 3, 4, 5])
housing["income_cat"].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Comparamos las proporciones de la variable income_cat entre el data set completo, el set de testing resultado de un muestreo aleatorio y un muestreo estratificado. Vemos que el muestreo estratificado representa mejor las proporciones originales del set completo, por lo tanto elegimos este para realizar la división de datos.

# %%
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_index, test_index in split.split(housing, housing["income_cat"]):
    strat_train_set = housing.loc[train_index]
    strat_test_set = housing.loc[test_index]

def income_cat_proportions(data):
    return data["income_cat"].value_counts() / len(data)


train_set, test_set = train_test_split(housing, test_size=0.2, random_state=42)

compare_props = pd.DataFrame({
    "Overall": income_cat_proportions(housing),
    "Stratified": income_cat_proportions(strat_test_set),
    "Random": income_cat_proportions(test_set),
}).sort_index()
compare_props["Rand. %error"] = 100 * compare_props["Random"] / compare_props["Overall"] - 100
compare_props["Strat. %error"] = 100 * compare_props["Stratified"] / compare_props["Overall"] - 100

compare_props
# Out:
#     Overall  Stratified    Random  Rand. %error  Strat. %error
# 1  0.039826    0.039729  0.040213      0.973236      -0.243309
# 2  0.318847    0.318798  0.324370      1.732260      -0.015195
# 3  0.350581    0.350533  0.358527      2.266446      -0.013820
# 4  0.176308    0.176357  0.167393     -5.056334       0.027480
# 5  0.114438    0.114583  0.109496     -4.318374       0.127011

# %% [markdown]
# # Procesamiento y limpieza de datos

# %%
#esto lo hacemos para que el pipeline funcione correctamente. Simplemente transforma el dataset en un ndArray
#para que luego pueda utilizarlo la transformacion con CombinedAttributesAdder
class ConvertToNDArray(BaseEstimator, TransformerMixin):
    def __init__(self): # no *args or **kargs
        return None
    def fit(self, X, y=None):
        return self  # nothing else to do
    def transform(self, X):
        return X.values

convert_toNdArray = ConvertToNDArray()

class CombinedAttributesAdder(BaseEstimator, TransformerMixin):
    def __init__(self, add_bedrooms_per_room=True,rooms_ix=3, bedrooms_ix=4, population_ix=5, households_ix=6): # no *args or **kargs
        self.add_bedrooms_per_room = add_bedrooms_per_room
        self.rooms_ix = rooms_ix 
        self.bedrooms_ix=bedrooms_ix 
        self.population_ix=population_ix 
        self.households_ix=households_ix
        
    def fit(self, X, y=None):
        return self  # nothing else to do
    
    def transform(self, X):
        rooms_per_household = X[:, self.rooms_ix] / X[:, self.households_ix]
        population_per_household = X[:, self.population_ix] / X[:, self.households_ix]
        if self.add_bedrooms_per_room:
            bedrooms_per_room = X[:, self.bedrooms_ix] / X[:, self.rooms_ix]
            return np.c_[X, rooms_per_household, population_per_household,
                         bedrooms_per_room]
        else:
            return np.c_[X, rooms_per_household, population_per_household]

# %%
def processingData(dataSet, targetFeature, categoricalFeature, col_names, extra_attribs):
        #quitamos los nan
        dataSet_withoutnan = dataSet.dropna().copy()
        
        #dividimos el dataset en las variables que se usan en la prediccion y la variable a predecir
        data = dataSet_withoutnan.drop(targetFeature, axis=1).copy() # drop labels for training set
        data_labels = dataSet_withoutnan[targetFeature].copy()
        
        #procesamos primero los datos numericos
        print("procesando los datos numericos...\n")
        numerical_data = data.drop([categoricalFeature,"longitude", "latitude"], axis=1)
        
        #obtenemos los indices de las columnas que luego vamos a combinar
        rooms_ix, bedrooms_ix, population_ix, households_ix = [
            data.columns.get_loc(c) for c in col_names] # get the column indices
        
        #generamos el dataframe con los atributos extra
        attr_adder = CombinedAttributesAdder(add_bedrooms_per_room=False)
        data_extra_attribs = attr_adder.transform(data.values)
        
        data_extra_attribs = pd.DataFrame(
            data_extra_attribs,
            columns=list(data.columns)+extra_attribs,
            index=numerical_data.index)
            
        num_pipeline = Pipeline([
        ('convert_toNdArray', ConvertToNDArray()),
        ('attribs_adder', CombinedAttributesAdder()),
        ('std_scaler', StandardScaler()),
        ])

        num_attribs = list(numerical_data)+extra_attribs
        
        #procesamos los datos categoricos
        print("procensando variables categoricas...\n")
        cat_attribs = [categoricalFeature]

        full_pipeline = ColumnTransformer([
                ("num", num_pipeline, num_attribs),
                ("cat", OneHotEncoder(), cat_attribs),
            ])

        data_prepared = full_pipeline.fit_transform(data_extra_attribs)
        
        #devolvemos los datos procesados y los objetivos
        print("procesamiento finalizado :D")
        return data_prepared, data_labels

# %%
train, train_labels = processingData(strat_train_set, "median_house_value", 
                "ocean_proximity", 
                ["total_rooms", "total_bedrooms", "population", "households"], 
                ["rooms_per_household", "population_per_household"])
# Out:
# procesando los datos numericos...
#
# procensando variables categoricas...
#
# procesamiento finalizado :D

# %%
test, test_labels = processingData(strat_test_set, "median_house_value", 
                "ocean_proximity", 
                ["total_rooms", "total_bedrooms", "population", "households"], 
                ["rooms_per_household", "population_per_household"])
# Out:
# procesando los datos numericos...
#
# procensando variables categoricas...
#
# procesamiento finalizado :D

# %% [markdown]
# # **Entrenamiento de los modelos**

# %%
def selectValuesForHyperparameter(initialValue, lastValue, jumps):
    rv = []
    for v in range(int(initialValue*100), int(lastValue*100),int(jumps*100)):
        rv.append(float(v/100));
    return rv

# %%
alphaValues = selectValuesForHyperparameter(0.8, 10, 0.2)    
print(alphaValues)
# Out:
# [0.8, 1.0, 1.2, 1.4, 1.6, 1.8, 2.0, 2.2, 2.4, 2.6, 2.8, 3.0, 3.2, 3.4, 3.6, 3.8, 4.0, 4.2, 4.4, 4.6, 4.8, 5.0, 5.2, 5.4, 5.6, 5.8, 6.0, 6.2, 6.4, 6.6, 6.8, 7.0, 7.2, 7.4, 7.6, 7.8, 8.0, 8.2, 8.4, 8.6, 8.8, 9.0, 9.2, 9.4, 9.6, 9.8]

# %% [markdown]
# ## [**Lasso**](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Lasso.html)
# Linear Model trained with L1 prior as regularizer (aka the Lasso)
#
# The optimization objective for Lasso is:
# $$(1 / (2 * n_{samples})) * ||y - Xw||^2_2 + \alpha * ||w||_1$$

# %% [markdown]
# ## Búsqueda del mejor hiperparámetro

# %%
lasso_params = {'alpha':alphaValues}
lasso = linear_model.Lasso(max_iter=5000)
clf_lasso = GridSearchCV(lasso, lasso_params, cv=10,
                                scoring='neg_mean_squared_error', #-> este scoring lo sacamos del Hands' On 
                                return_train_score=True)
clf_lasso.fit(train, train_labels)
clf_lasso.best_params_        
#sorted(clf.cv_results_.keys())
# Out:
# probando con maxima cantidad de iteraciones :1000
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5440914875654.258, tolerance: 19949120660.01658
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5421631189931.484, tolerance: 19671349418.769135
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5427080473362.648, tolerance: 19754226082.5009
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5402729369234.125, tolerance: 19646115645.59088
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5453250395932.453, tolerance: 19755307956.548016
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5368859349901.523, tolerance: 19629946841.89788
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5438896777856.234, tolerance: 19764612471.127106
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5476734379696.008, tolerance: 19672161494.29452
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5372643840866.742, tolerance: 19674852893.232933
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5499669065677.305, tolerance: 19789401647.086506
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5441406294995.0, tolerance: 19949120660.01658
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5422133059711.875, tolerance: 19671349418.769135
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5427577630012.844, tolerance: 19754226082.5009
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5403234603486.906, tolerance: 19646115645.59088
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5453786494102.664, tolerance: 19755307956.548016
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5369363011341.758, tolerance: 19629946841.89788
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5439389808308.914, tolerance: 19764612471.127106
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5477229945118.031, tolerance: 19672161494.29452
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5373153538534.102, tolerance: 19674852893.232933
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5500107868214.461, tolerance: 19789401647.086506
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5441863469875.875, tolerance: 19949120660.01658
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5422600688310.898, tolerance: 19671349418.769135
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5428040544941.008, tolerance: 19754226082.5009
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5403705597294.453, tolerance: 19646115645.59088
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5454285581770.031, tolerance: 19755307956.548016
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5369832396033.859, tolerance: 19629946841.89788
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5439848583896.133, tolerance: 19764612471.127106
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5477691244356.805, tolerance: 19672161494.29452
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5373628986681.102, tolerance: 19674852893.232933
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5500509650403.133, tolerance: 19789401647.086506
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5442286400074.68, tolerance: 19949120660.01658
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5423034075470.344, tolerance: 19671349418.769135
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5428469217896.547, tolerance: 19754226082.5009
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5404142350542.039, tolerance: 19646115645.59088
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5454747658613.281, tolerance: 19755307956.548016
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5370267503850.3125, tolerance: 19629946841.89788
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5440273104449.734, tolerance: 19764612471.127106
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5478118277264.0, tolerance: 19672161494.29452
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5374070184920.508, tolerance: 19674852893.232933
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5500874412225.594, tolerance: 19789401647.086506
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5442675085498.25, tolerance: 19949120660.01658
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5423433221109.797, tolerance: 19671349418.769135
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5428863648758.3125, tolerance: 19754226082.5009
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5404544863126.375, tolerance: 19646115645.59088
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5455172724415.203, tolerance: 19755307956.548016
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5370668334770.578, tolerance: 19629946841.89788
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5440663369858.883, tolerance: 19764612471.127106
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5478511043841.633, tolerance: 19672161494.29452
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5374477133081.078, tolerance: 19674852893.232933
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5501202153536.984, tolerance: 19789401647.086506
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5443029526027.656, tolerance: 19949120660.01658
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5423798125143.258, tolerance: 19671349418.769135
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5429223837460.773, tolerance: 19754226082.5009
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5404913134989.1875, tolerance: 19646115645.59088
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5455560779135.547, tolerance: 19755307956.548016
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5371034888671.602, tolerance: 19629946841.89788
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5441019380105.016, tolerance: 19764612471.127106
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5478869544015.141, tolerance: 19672161494.29452
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5374849831037.703, tolerance: 19674852893.232933
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5501492874368.617, tolerance: 19789401647.086506
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5443349721677.75, tolerance: 19949120660.01658
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5424128787532.102, tolerance: 19671349418.769135
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5429549783970.297, tolerance: 19754226082.5009
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5405247166124.867, tolerance: 19646115645.59088
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5455911822687.07, tolerance: 19755307956.548016
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5371367165594.664, tolerance: 19629946841.89788
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5441341135147.125, tolerance: 19764612471.127106
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5479193777768.977, tolerance: 19672161494.29452
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5375188278750.852, tolerance: 19674852893.232933
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5501746574736.625, tolerance: 19789401647.086506
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5443635672441.3125, tolerance: 19949120660.01658
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5424425208234.078, tolerance: 19671349418.769135
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5429841488256.945, tolerance: 19754226082.5009
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5405546956516.625, tolerance: 19646115645.59088
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5456225855068.508, tolerance: 19755307956.548016
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5371665165510.945, tolerance: 19629946841.89788
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5441628634997.539, tolerance: 19764612471.127106
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5479483745117.156, tolerance: 19672161494.29452
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5375492476160.219, tolerance: 19674852893.232933
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5501963254574.102, tolerance: 19789401647.086506
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5443887378241.297, tolerance: 19949120660.01658
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5424687387282.273, tolerance: 19671349418.769135
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5430098950309.648, tolerance: 19754226082.5009
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5405812506132.1875, tolerance: 19646115645.59088
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5456502876201.5, tolerance: 19755307956.548016
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5371928888402.523, tolerance: 19629946841.89788
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5441881879579.609, tolerance: 19764612471.127106
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5479739446008.93, tolerance: 19672161494.29452
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5375762423200.555, tolerance: 19674852893.232933
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5502142913905.578, tolerance: 19789401647.086506
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1137004382664.8125, tolerance: 19949120660.01658
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 565182831042.9453, tolerance: 19671349418.769135
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1133758443297.25, tolerance: 19754226082.5009
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5406043814995.508, tolerance: 19646115645.59088
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5456742886115.242, tolerance: 19755307956.548016
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5372158334259.148, tolerance: 19629946841.89788
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5442100868938.086, tolerance: 19764612471.127106
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5479960880466.656, tolerance: 19672161494.29452
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5375998119900.859, tolerance: 19674852893.232933
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1152402553400.2031, tolerance: 19789401647.086506
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1137218975666.4453, tolerance: 19949120660.01658
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1130984889433.1719, tolerance: 19671349418.769135
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1134222333016.1953, tolerance: 19754226082.5009
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1130988653429.9453, tolerance: 19646115645.59088
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1141527227974.1406, tolerance: 19755307956.548016
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1122658621176.625, tolerance: 19629946841.89788
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1135944703914.6797, tolerance: 19764612471.127106
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1145605508040.7578, tolerance: 19672161494.29452
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1123663489952.789, tolerance: 19674852893.232933
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1153769081149.1562, tolerance: 19789401647.086506
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1137317521190.8203, tolerance: 19949120660.01658
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1131059745642.2031, tolerance: 19671349418.769135
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1134316648869.586, tolerance: 19754226082.5009
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1131073139918.7422, tolerance: 19646115645.59088
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1141622986094.086, tolerance: 19755307956.548016
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1122743375582.3281, tolerance: 19629946841.89788
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1136025071781.7656, tolerance: 19764612471.127106
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1145681686031.8516, tolerance: 19672161494.29452
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1123774637198.7188, tolerance: 19674852893.232933
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1153800894990.0781, tolerance: 19789401647.086506
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1137452727605.9062, tolerance: 19949120660.01658
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1131184596875.3281, tolerance: 19671349418.769135
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1134450745565.914, tolerance: 19754226082.5009
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1131192839271.4844, tolerance: 19646115645.59088
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1141726690557.836, tolerance: 19755307956.548016
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1122858398520.9297, tolerance: 19629946841.89788
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1136134172680.4453, tolerance: 19764612471.127106
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1145794897765.1797, tolerance: 19672161494.29452
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1123883851284.289, tolerance: 19674852893.232933
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1153883143073.086, tolerance: 19789401647.086506
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1137595942787.375, tolerance: 19949120660.01658
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1131328086622.8047, tolerance: 19671349418.769135
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1134595157552.7734, tolerance: 19754226082.5009
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1131334123297.2344, tolerance: 19646115645.59088
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1141858500300.414, tolerance: 19755307956.548016
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1122998624088.7344, tolerance: 19629946841.89788
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1136268589260.6953, tolerance: 19764612471.127106
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1145932203749.7422, tolerance: 19672161494.29452
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1124020672284.8672, tolerance: 19674852893.232933
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1153981009276.3047, tolerance: 19789401647.086506
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1137735895412.6094, tolerance: 19949120660.01658
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1131471024262.9375, tolerance: 19671349418.769135
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1134736763464.3594, tolerance: 19754226082.5009
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1131476629100.1406, tolerance: 19646115645.59088
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1141993980044.7969, tolerance: 19755307956.548016
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1123141076460.0703, tolerance: 19629946841.89788
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1136405375565.8203, tolerance: 19764612471.127106
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1146071022777.6562, tolerance: 19672161494.29452
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1124162566223.7969, tolerance: 19674852893.232933
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1154076066416.7266, tolerance: 19789401647.086506
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1137870444038.8125, tolerance: 19949120660.01658
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1131608919316.039, tolerance: 19671349418.769135
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1134873034877.8125, tolerance: 19754226082.5009
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1131614710689.414, tolerance: 19646115645.59088
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1142124550086.125, tolerance: 19755307956.548016
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1123279233540.6797, tolerance: 19629946841.89788
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1136537954610.8984, tolerance: 19764612471.127106
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1146205389331.3594, tolerance: 19672161494.29452
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1154164518140.9531, tolerance: 19789401647.086506
# ...
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5438997261660.703, tolerance: 19764612471.127106
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5476837285485.023, tolerance: 19672161494.29452
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5372761229377.828, tolerance: 19674852893.232933
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5499716109229.4375, tolerance: 19789401647.086506
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5441298223425.125, tolerance: 19949120660.01658
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5422035589596.742, tolerance: 19671349418.769135
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5427475528952.391, tolerance: 19754226082.5009
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5403140711665.805, tolerance: 19646115645.59088
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5453721260017.141, tolerance: 19755307956.548016
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5369266782790.047, tolerance: 19629946841.89788
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5439283319587.75, tolerance: 19764612471.127106
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5477125816514.523, tolerance: 19672161494.29452
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5373064068340.328, tolerance: 19674852893.232933
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5499945519025.523, tolerance: 19789401647.086506
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1135851648371.9688, tolerance: 19949120660.01658
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1129570444540.7656, tolerance: 19671349418.769135
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1132839081811.4453, tolerance: 19754226082.5009
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1129597813049.8203, tolerance: 19646115645.59088
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1140136508762.5625, tolerance: 19755307956.548016
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1121257496598.2031, tolerance: 19629946841.89788
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1134595006373.1875, tolerance: 19764612471.127106
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1144229040650.2578, tolerance: 19672161494.29452
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1122327388373.8828, tolerance: 19674852893.232933
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1152615865167.1328, tolerance: 19789401647.086506
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1136013328963.2031, tolerance: 19949120660.01658
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1129717882271.5312, tolerance: 19671349418.769135
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1132997582009.8984, tolerance: 19754226082.5009
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1129718806682.3438, tolerance: 19646115645.59088
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1140233479631.4375, tolerance: 19755307956.548016
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1121384687224.3281, tolerance: 19629946841.89788
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1134704822930.0938, tolerance: 19764612471.127106
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1144352812027.125, tolerance: 19672161494.29452
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1122403490819.9453, tolerance: 19674852893.232933
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1152735580009.4844, tolerance: 19789401647.086506
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1136167279136.8594, tolerance: 19949120660.01658
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1129875036985.8828, tolerance: 19671349418.769135
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1133153253573.961, tolerance: 19754226082.5009
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1129876615032.7031, tolerance: 19646115645.59088
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1140398507130.289, tolerance: 19755307956.548016
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1121542290331.3125, tolerance: 19629946841.89788
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1134856927540.0, tolerance: 19764612471.127106
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1144506582375.3984, tolerance: 19672161494.29452
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1122561990569.914, tolerance: 19674852893.232933
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1152858118147.5703, tolerance: 19789401647.086506
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1136312782285.9922, tolerance: 19949120660.01658
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1130023644914.4062, tolerance: 19671349418.769135
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1133300454994.1328, tolerance: 19754226082.5009
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1130025700548.7734, tolerance: 19646115645.59088
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1121691219876.7734, tolerance: 19629946841.89788
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1152970701684.8203, tolerance: 19789401647.086506
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1121831675504.1172, tolerance: 19629946841.89788
#   model = cd_fast.enet_coordinate_descent(
# /home/bruno/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6035845046246.195, tolerance: 21923264573.215584
#   model = cd_fast.enet_coordinate_descent(
# {'alpha': 1.0}

# %%
clf_lasso.cv_results_["mean_train_score"]
# Out:
# array([-4.59641140e+09, -4.59641460e+09, -4.59641853e+09, -4.59642316e+09,
#        -4.59642851e+09, -4.59643457e+09, -4.59644134e+09, -4.59644883e+09,
#        -4.59645703e+09, -4.59646594e+09, -4.59647557e+09, -4.59648590e+09,
#        -4.59649696e+09, -4.59650872e+09, -4.59652120e+09, -4.59653439e+09,
#        -4.59654829e+09, -4.59656291e+09, -4.59657824e+09, -4.59659428e+09,
#        -4.59661104e+09, -4.59662850e+09, -4.59664669e+09, -4.59666558e+09,
#        -4.59668429e+09, -4.59670126e+09, -4.59671883e+09, -4.59673699e+09,
#        -4.59675574e+09, -4.59677509e+09, -4.59679503e+09, -4.59681557e+09,
#        -4.59683671e+09, -4.59685845e+09, -4.59688078e+09, -4.59690371e+09,
#        -4.59692723e+09, -4.59695134e+09, -4.59697606e+09, -4.59700137e+09,
#        -4.59702727e+09, -4.59705376e+09, -4.59708085e+09, -4.59710854e+09,
#        -4.59713682e+09, -4.59716569e+09])

# %% [markdown]
# ## Entrenamos el modelo con el hiperparámetro seleccionado

# %%
lasso = linear_model.LassoCV(alphas=[clf.best_params_['alpha']],
                               max_iter=5000, 
                               cv=10, 
                               random_state=0).fit(train, train_labels)

# %%
print("Los coeficientes resultantes del entrenamiento son :"+str(lasso.coef_)+'\n')
print("El termino de regularizacion resultante es :"+str(lasso.intercept_))
# Out:
# Los coeficientes resultantes del entrenamiento son :[ 15659.04621939  -8548.14182552  19112.32089297 -10624.95154425
#   -6254.58827967  63071.04189633  20024.90817099   1133.97131072
#    -253.39550063  15093.77040809   -644.39160509  28567.75658632
#       0.         -68874.23445692 143504.46572524  -4393.12888509
#    6220.52277821]
#
# El termino de regularizacion resultante es :228727.10573663274

# %% [markdown]
# ## Testingggggggggggggggggggggg

# %%
housing_predictions_lasso = lasso.predict(test)
lin_mse_lasso = mean_squared_error(test_labels, housing_predictions_lasso)
lin_rmse_lasso = np.sqrt(lin_mse_lasso)
lin_rmse_lasso
# Out:
# 65776.55955190104

# %%
#parametro optimo encontrado es 1.0 con grid search 
len(housing_predictions_lasso)
# Out:
# 4079

# %% [markdown]
# ## [**Ridge**](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Ridge.html)
# Linear least squares with l2 regularization.
#
# Minimizes the objective function:
# $$||y - Xw||^2_2 + \alpha * ||w||^2_2$$

# %% [markdown]
# ## Búsqueda del mejor hiperparámetro

# %%
alphaValues = selectValuesForHyperparameter(1, 10, 0.1)    
ridge_params = {'alpha':alphaValues}
ridge = Ridge(max_iter=5000)
clf_ridge = GridSearchCV(ridge, ridge_params, cv=10,
                                    scoring='neg_mean_squared_error',
                                    return_train_score=True)
clf_ridge.fit(train, train_labels)
sorted(clf_ridge.cv_results_.keys())
clf_ridge.best_params_
# Out:
# {'alpha': 1.0}

# %%
clf_ridge.cv_results_["mean_train_score"]
# Out:
# array([-4.48467778e+09, -4.48472296e+09, -4.48476811e+09, -4.48481302e+09,
#        -4.48485755e+09, -4.48490156e+09, -4.48494496e+09, -4.48498770e+09,
#        -4.48502970e+09, -4.48507094e+09, -4.48511139e+09, -4.48515103e+09,
#        -4.48518986e+09, -4.48522787e+09, -4.48526506e+09, -4.48530145e+09,
#        -4.48533703e+09, -4.48537183e+09, -4.48540584e+09, -4.48543910e+09,
#        -4.48547162e+09, -4.48550340e+09, -4.48553447e+09, -4.48556486e+09,
#        -4.48559456e+09, -4.48562361e+09, -4.48565202e+09, -4.48567980e+09,
#        -4.48570698e+09, -4.48573357e+09, -4.48575959e+09, -4.48578506e+09,
#        -4.48580999e+09, -4.48583439e+09, -4.48585829e+09, -4.48588169e+09,
#        -4.48590461e+09, -4.48592707e+09, -4.48594908e+09, -4.48597065e+09,
#        -4.48599179e+09, -4.48601252e+09, -4.48603285e+09, -4.48605279e+09,
#        -4.48607235e+09, -4.48609155e+09, -4.48611039e+09, -4.48612888e+09,
#        -4.48614703e+09, -4.48616486e+09, -4.48618237e+09, -4.48619956e+09,
#        -4.48621646e+09, -4.48623307e+09, -4.48624939e+09, -4.48626543e+09,
#        -4.48628121e+09, -4.48629672e+09, -4.48631198e+09, -4.48632699e+09,
#        -4.48634176e+09, -4.48635629e+09, -4.48637060e+09, -4.48638468e+09,
#        -4.48639854e+09, -4.48641220e+09, -4.48642565e+09, -4.48643889e+09,
#        -4.48645194e+09, -4.48646480e+09, -4.48647748e+09, -4.48648997e+09,
#        -4.48650229e+09, -4.48651443e+09, -4.48652641e+09, -4.48653822e+09,
#        -4.48654987e+09, -4.48656137e+09, -4.48657271e+09, -4.48658391e+09,
#        -4.48659496e+09, -4.48660586e+09, -4.48661663e+09, -4.48662727e+09,
#        -4.48663777e+09, -4.48664814e+09, -4.48665839e+09, -4.48666851e+09,
#        -4.48667852e+09, -4.48668840e+09])

# %% [markdown]
# ## Entrenamos el modelo con el hiperparámetro seleccionado

# %%
ridge = linear_model.RidgeCV(alphas=[clf_ridge.best_params_['alpha']],
                             cv=10, 
                             scoring='neg_mean_squared_error')
ridge.fit(train, train_labels)
# Out:
# RidgeCV(alphas=array([1.]), cv=10, scoring='neg_mean_squared_error')

# %%
print("Los coeficientes resultantes del entrenamiento son :"+str(ridge.coef_))
print("El termino de regularizacion resultante es :"+str(ridge.intercept_))
# Out:
# Los coeficientes resultantes del entrenamiento son :[ 15666.70149366  -8562.11077082  19168.54799223 -10606.57464312
#   -6308.24529365  62961.10723097  20099.61495475   1130.84909004
#    -255.59633289  15083.1613671    -589.48798161  28569.23978754
#   -7299.3894863  -76158.10213319  96229.22126471 -11700.9318469
#   -1070.79779939]
# El termino de regularizacion resultante es :236026.3360349962

# %% [markdown]
# ## Testing goes brrrrrrrrrr

# %%
housing_predictions_ridge = ridge.predict(test)
lin_mse_ridge = mean_squared_error(test_labels, housing_predictions_ridge)
lin_rmse_ridge = np.sqrt(lin_mse_ridge)
lin_rmse_ridge
# Out:
# 65801.19906127549

# %% [markdown]
# ### [Elastic Net](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.ElasticNet.html)
#
# $$1 / (2 * n_{samples}) * ||y - Xw||^2_2 + \alpha * l_{1_{ratio}} * ||w||_1 + 0.5 * \alpha * (1 - l_{1_{ratio}}) * ||w||^2_2$$

# %% [markdown]
# ## Búsqueda del mejor hiperparámetro

# %%
alphaValues = selectValuesForHyperparameter(0.2, 10, 0.2);  
l1Values = selectValuesForHyperparameter(0.05, 1, 0.05);  

elastic_params = {'alpha':alphaValues, 'l1_ratio':l1Values}
elastic = linear_model.ElasticNet(max_iter=5000)
clf_elastic = GridSearchCV(elastic, elastic_params, cv=10,
                                    scoring='neg_mean_squared_error', #-> este scoring lo sacamos del Hands' On 
                                    return_train_score=True)
clf_elastic.fit(train, train_labels)
sorted(clf_elastic.cv_results_.keys())
clf_elastic.best_params_
# Out:
# {'alpha': 0.2, 'l1_ratio': 0.95}

# %% [markdown]
# ## Entrenamos el modelo con el hiperparámetro seleccionado

# %%
elastic = linear_model.ElasticNetCV(alphas=[clf_elastic.best_params_['alpha']],
                                  l1_ratio=[clf_elastic.best_params_['l1_ratio']],
                                  max_iter=5000,
                                  cv=10)
elastic.fit(train, train_labels)
# Out:
# ElasticNetCV(alphas=[0.2], cv=10, l1_ratio=[0.95], max_iter=5000)

# %%
print("Los coeficientes resultantes del entrenamiento son :"+str(elastic.coef_)+'\n')
print("El termino de regularizacion resultante es :"+str(elastic.intercept_))
# Out:
# Los coeficientes resultantes del entrenamiento son :[ 15873.24523521  -7964.48128399  13799.55562246  -9188.08801632
#   -1640.63152351  51877.96841974  26966.68222269   1404.48689787
#    -282.2135522   13411.97704737   4497.11371369  28463.41853433
#   16187.9647071  -50545.03073984   1998.90230222  10991.51590509
#   21309.63926337]
#
# El termino de regularizacion resultante es :212106.05938455596

# %% [markdown]
# ## Testing Cuchau

# %%
housing_predictions_elastic = elastic.predict(test)
lin_mse_elastic = mean_squared_error(test_labels, housing_predictions_elastic)
lin_rmse_elastic = np.sqrt(lin_mse_elastic)
lin_rmse_elastic
# Out:
# 66101.03208781325

# %% [markdown]
# # Comparación de los RMSE

# %%
print("El RMSE para Elastic Net es:"+str(lin_rmse_elastic)+'\n')
print("El RMSE para Ridge es:"+str(lin_rmse_ridge)+'\n')
print("El RMSE para Lasso es:"+str(lin_rmse_lasso)+'\n')
# Out:
# El RMSE para Elastic Net es:66101.03208781325
#
# El RMSE para Ridge es:65801.19906127549
#
# El RMSE para Lasso es:65776.55955190104
